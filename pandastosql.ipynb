# %%
# !pip install pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/45.7 kB ? eta -:--:--
#    -------------------------- ------------- 30.7/45.7 kB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 30.7/45.7 kB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 41.0/45.7 kB 245.8 kB/s eta 0:00:01
#    ---------------------------------------- 45.7/45.7 kB 251.6 kB/s eta 0:00:00
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv(r'C:\Users\HP\Documents\da-practice\fifa_updated.csv')

engine = create_engine('mysql+pymysql://root:DHNiv#1107@localhost/new_schema')

df.to_sql('fifa21', engine, if_exists='replace', index=False)
# Out:
# 18979
